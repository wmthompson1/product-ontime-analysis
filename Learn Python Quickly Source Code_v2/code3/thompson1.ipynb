# %% [markdown]
# ### Notebook

# %%
# print("hello")
x = 3 + 4
x + 1
# Out:
# 8

# %%
def greeting():
    
    print("hello again-3")
    
greeting()

# %%
squares = [x**2 for x in range(1, 6)]
# Result: [1, 4, 9, 16, 25]
print(squares)
